# %%
import matplotlib.pyplot as plt

# %%
cnn_time = [17.775956392288208, 19.8178973197937, 21.816837072372437, 31.076699018478394, \
            46.31832957267761, 80.8678469657898, 169.42654252052307, 286.3897075653076]
lstm_time = [10.282740831375122, 10.629135131835938, 10.303154230117798, 12.20218539237976, \
             14.21000051498413, 20.247140169143677, 56.0874125957489, 126.84333872795105]
rnn_time = [9.478646993637085, 9.289943218231201, 9.754751443862915, 9.39123797416687, 10.234161138534546, 11.01068377494812, 19.746299505233765, 47.2914502620697]
units_arr = [10, 20, 30, 50, 100, 200, 500, 1000]

# %%
plt.plot(units_arr, cnn_time, marker='o', linestyle='-', color = 'red', label = 'CNN')  # 'o' marker style with solid line
plt.plot(units_arr, lstm_time, marker='o', linestyle='-', color = 'blue', label = 'LSTM')
plt.plot(units_arr, rnn_time, marker='o', linestyle='-', color = 'green', label = 'RNN')
plt.xlabel('Number of Units')
plt.ylabel('Runtime (in sec)')
plt.title('Runtime vs Units\n Epileptic Seizure Detection')
plt.legend()
plt.ylim(0, 700)
plt.grid(True)  # Add grid lines
plt.savefig('EEG.jpeg')
plt.show()
